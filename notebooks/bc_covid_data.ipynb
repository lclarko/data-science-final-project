# %% [markdown]
# # Collecting and Filtering Canadian Covid-19 Metrics
# * Covid-19 data sources from [The Government of Canada](https://health-infobase.canada.ca/covid-19/epidemiological-summary-covid-19-cases.html)
# * Daily numbers for British Columbia are filtered out and exported from here. This entrie notebook will be reduced to a function.

# %%
import pandas as pd
import numpy as np
import re
import string

# %%
df = pd.read_csv('https://health-infobase.canada.ca/src/data/covidLive/covid19-download.csv')

# %%
df.columns
# Out:
# Index(['pruid', 'prname', 'prnameFR', 'date', 'numconf', 'numprob',
#        'numdeaths', 'numtotal', 'numtested', 'numrecover', 'percentrecover',
#        'ratetested', 'numtoday', 'percentoday', 'ratetotal', 'ratedeaths',
#        'numdeathstoday', 'percentdeath', 'numtestedtoday', 'numrecoveredtoday',
#        'percentactive', 'numactive', 'rateactive', 'numtotal_last14',
#        'ratetotal_last14', 'numdeaths_last14', 'ratedeaths_last14',
#        'numtotal_last7', 'ratetotal_last7', 'numdeaths_last7',
#        'ratedeaths_last7', 'avgtotal_last7', 'avgincidence_last7',
#        'avgdeaths_last7', 'avgratedeaths_last7'],
#       dtype='object')

# %%
df.groupby('prname').sum()
# Out:
#                            pruid   numconf  numprob  numdeaths  numtotal  \
# prname
# Alberta                    12432   3149052        0    47141.0   3145187
# British Columbia           16107   1478222        0    44499.0   1478222
# Canada                       273  29932717     3282  1821879.0  29935973
# Manitoba                   11822    417157     1799     5882.0    418954
# New Brunswick               3341     45701       51      462.0     45752
# Newfoundland and Labrador   2570     63899       69      748.0     63968
# Northwest Territories      15677      1389        0        0.0      1389
# Nova Scotia                 3084    239482       45    13037.0    239527
# Nunavut                    15934       593        0        0.0       593
# Ontario                     9555   9664323        0   567547.0   9664323
# Prince Edward Island        2827      9848        0        0.0      9848
# Quebec                      6336  14508931     1218  1138581.0  14510149
# Repatriated travellers     25443      3265        0        0.0      3265
# Saskatchewan               12079    351365      100     3958.0    351465
# Yukon                      15420      3321        0       24.0      3321
#
#                               numtested  numrecover  percentrecover  \
# prname
# Alberta                    1.451244e+08   2586348.0        18216.29
# British Columbia           6.596515e+07   1145685.0        18742.59
# Canada                     1.054627e+09  22903678.0        16030.36
# Manitoba                   2.644939e+07    212666.0        16089.49
# New Brunswick              1.084456e+07     39441.0        20255.35
# Newfoundland and Labrador  6.302375e+06     57144.0        21136.21
# Northwest Territories      7.502460e+05      1215.0        21151.87
# Nova Scotia                1.575546e+07    209221.0        19626.12
# Nunavut                    3.648210e+05         4.0            3.37
# Ontario                    5.344019e+08   8135896.0        18379.43
# Prince Edward Island       5.126645e+06      8888.0        20936.06
# Quebec                     2.194338e+08  10233894.0        14156.81
# Repatriated travellers     1.896800e+04      2513.0        19330.78
# Saskatchewan               2.354020e+07    279119.0        18441.76
# Yukon                      5.106660e+05      2942.0        20738.84
#
#                            ratetested  numtoday  ...  numdeaths_last14  \
# prname                                           ...
# Alberta                    33199239.0     46865  ...            5879.0
# British Columbia           13007447.0     25467  ...            4176.0
# Canada                     28056605.0    330503  ...          153959.0
# Manitoba                   19313653.0     13544  ...            2321.0
# New Brunswick              13960076.0       430  ...              84.0
# Newfoundland and Labrador  12084112.0       319  ...              56.0
# Northwest Territories      16736846.0        15  ...               0.0
# Nova Scotia                16219426.0      1179  ...             910.0
# Nunavut                     9407448.0       130  ...               0.0
# Ontario                    36686930.0    103912  ...           47073.0
# Prince Edward Island       32664819.0        68  ...               0.0
# Quebec                     25861491.0    132042  ...           93017.0
# Repatriated travellers            0.0        13  ...               0.0
# Saskatchewan               20043391.0      6473  ...             430.0
# Yukon                      12499786.0        28  ...              14.0
#
#                            ratedeaths_last14  numtotal_last7  ratetotal_last7  \
# prname
# Alberta                               134.43        300454.0          6873.30
# British Columbia                       82.68        170256.0          3357.27
# Canada                                409.61       2204606.0          5865.10
# Manitoba                              169.43         87089.0          6359.40
# New Brunswick                          10.85          2701.0           347.80
# Newfoundland and Labrador              10.68          2119.0           406.26
# Northwest Territories                   0.00           102.0           227.46
# Nova Scotia                            93.56          7982.0           821.65
# Nunavut                                 0.00           553.0          1426.02
# Ontario                               323.10        694615.0          4768.60
# Prince Edward Island                    0.00           462.0           294.33
# Quebec                               1096.22        897974.0         10583.11
# Repatriated travellers                  0.00            12.0             0.00
# Saskatchewan                           36.98         40099.0          3414.22
# Yukon                                  34.30           162.0           396.73
#
#                            numdeaths_last7  ratedeaths_last7  avgtotal_last7  \
# prname
# Alberta                             3152.0             72.08         42923.0
# British Columbia                    2179.0             43.27         24342.0
# Canada                             78655.0            209.25        314945.0
# Manitoba                            1392.0            101.63         12440.0
# New Brunswick                         42.0              5.46           376.0
# Newfoundland and Labrador             28.0              5.32           292.0
# Northwest Territories                  0.0              0.00            14.0
# Nova Scotia                          455.0             46.81          1131.0
# Nunavut                                0.0              0.00            75.0
# Ontario                            24001.0            164.68         99239.0
# Prince Edward Island                   0.0              0.00            48.0
# Quebec                             47174.0            555.93        128282.0
# Repatriated travellers                 0.0              0.00             2.0
# Saskatchewan                         225.0             19.45          5727.0
# Yukon                                  7.0             17.15            10.0
#
#                            avgincidence_last7  avgdeaths_last7  \
# prname
# Alberta                                981.84            446.0
# British Columbia                       479.65            306.0
# Canada                                 837.87          11244.0
# Manitoba                               908.37            180.0
# New Brunswick                           49.80              0.0
# Newfoundland and Labrador               58.03              0.0
# Northwest Territories                   32.50              0.0
# Nova Scotia                            117.10             50.0
# Nunavut                                203.74              0.0
# Ontario                                681.16           3428.0
# Prince Edward Island                    41.92              0.0
# Quebec                                1511.88           6743.0
# Repatriated travellers                   0.00              0.0
# Saskatchewan                           487.75             10.0
# Yukon                                   56.70              0.0
#
#                            avgratedeaths_last7
# prname
# Alberta                                  10.38
# British Columbia                          6.23
# Canada                                   30.05
# Manitoba                                 14.42
# New Brunswick                             0.84
# Newfoundland and Labrador                 0.80
# Northwest Territories                     0.00
# Nova Scotia                               6.52
# Nunavut                                   0.00
# Ontario                                  23.45
# Prince Edward Island                      0.00
# Quebec                                   79.46
# Repatriated travellers                    0.00
# Saskatchewan                              2.48
# Yukon                                     2.45
#
# [15 rows x 32 columns]

# %%
df_bc = df[df.prname == 'British Columbia']

# %%
df_bc[['date','numtoday']].tail(1)
df_bc[df_bc.numtoday == 0]
# Out:
#       pruid            prname              prnameFR        date  numconf  \
# 13       59  British Columbia  Colombie-Britannique  2020-02-24        6
# 19       59  British Columbia  Colombie-Britannique  2020-02-26        7
# 22       59  British Columbia  Colombie-Britannique  2020-02-27        7
# 25       59  British Columbia  Colombie-Britannique  2020-02-29        7
# 40       59  British Columbia  Colombie-Britannique  2020-03-06       21
# ...     ...               ...                   ...         ...      ...
# 3372     59  British Columbia  Colombie-Britannique  2020-10-18    11189
# 3462     59  British Columbia  Colombie-Britannique  2020-10-24    12554
# 3477     59  British Columbia  Colombie-Britannique  2020-10-25    12554
# 3882     59  British Columbia  Colombie-Britannique  2020-11-21    25474
# 3897     59  British Columbia  Colombie-Britannique  2020-11-22    25474
#
#       numprob  numdeaths  numtotal  numtested  numrecover  ...  \
# 13          0        0.0         6        NaN         NaN  ...
# 19          0        0.0         7        NaN         NaN  ...
# 22          0        0.0         7        NaN         NaN  ...
# 25          0        0.0         7        NaN         NaN  ...
# 40          0        0.0        21        NaN         NaN  ...
# ...       ...        ...       ...        ...         ...  ...
# 3372        0      251.0     11189   543791.0      9387.0  ...
# 3462        0      256.0     12554   581804.0     10247.0  ...
# 3477        0      256.0     12554   581804.0     10247.0  ...
# 3882        0      331.0     25474   735429.0     17477.0  ...
# 3897        0      331.0     25474   735429.0     17477.0  ...
#
#       numdeaths_last14  ratedeaths_last14  numtotal_last7  ratetotal_last7  \
# 13                 NaN                NaN             NaN              NaN
# 19                 NaN                NaN             NaN              NaN
# 22                 NaN                NaN             NaN              NaN
# 25                 NaN                NaN             NaN              NaN
# 40                 NaN                NaN             NaN              NaN
# ...                ...                ...             ...              ...
# 3372              13.0               0.26          1004.0            19.80
# 3462              11.0               0.22          1365.0            26.92
# 3477              11.0               0.22          1365.0            26.92
# 3882              55.0               1.08          3835.0            75.62
# 3897              55.0               1.08          3176.0            62.63
#
#       numdeaths_last7  ratedeaths_last7  avgtotal_last7  avgincidence_last7  \
# 13                NaN               NaN             NaN                 NaN
# 19                NaN               NaN             NaN                 NaN
# 22                NaN               NaN             NaN                 NaN
# 25                NaN               NaN             NaN                 NaN
# 40                NaN               NaN             NaN                 NaN
# ...               ...               ...             ...                 ...
# 3372              6.0              0.12           143.0                2.83
# 3462              5.0              0.10           195.0                3.85
# 3477              5.0              0.10           195.0                3.85
# 3882             41.0              0.81           548.0               10.80
# 3897             41.0              0.81           454.0                8.95
#
#       avgdeaths_last7  avgratedeaths_last7
# 13                NaN                  NaN
# 19                NaN                  NaN
# 22                NaN                  NaN
# 25                NaN                  NaN
# 40                NaN                  NaN
# ...               ...                  ...
# 3372              1.0                 0.02
# 3462              1.0                 0.01
# 3477              1.0                 0.01
# 3882              6.0                 0.12
# 3897              6.0                 0.12
#
# [71 rows x 35 columns]

# %%
bc_df = df_bc[['prname', 'date', 'numconf', 'numdeaths', 'numtotal',
       'numtoday', 'percentoday', 'ratetotal', 'ratedeaths',
       'numdeathstoday', 'numactive', 'numtotal_last14',
       'ratetotal_last14', 'numdeaths_last14', 'ratedeaths_last14',
       'numtotal_last7', 'ratetotal_last7', 'numdeaths_last7',
       'ratedeaths_last7', 'avgtotal_last7', 'avgincidence_last7',
       'avgdeaths_last7']].groupby('date').sum()

bc_df = bc_df.reset_index().sort_values(by='date')
bc_df = bc_df[['date','numtoday','numtotal_last7','numdeathstoday','numdeaths_last7','numactive']]
bc_df.head()
bc_df.to_pickle('bc_covid_data.pkl')

# %%
bc_df.set_index('date').sort_index(ascending=False)
# Out:
#             numtoday  numtotal_last7  numdeathstoday  numdeaths_last7  \
# date
# 2020-11-22         0          3176.0             0.0             41.0
# 2020-11-21         0          3835.0             0.0             41.0
# 2020-11-20       516          4489.0            10.0             41.0
# 2020-11-19       536          4590.0             1.0             33.0
# 2020-11-18       761          4648.0            10.0             36.0
# ...              ...             ...             ...              ...
# 2020-02-24         0             0.0             0.0              0.0
# 2020-02-21         1             0.0             0.0              0.0
# 2020-02-16         1             0.0             0.0              0.0
# 2020-02-08         3             0.0             0.0              0.0
# 2020-01-31         1             0.0             0.0              0.0
#
#             numactive
# date
# 2020-11-22     7666.0
# 2020-11-21     7666.0
# 2020-11-20     7666.0
# 2020-11-19     7431.0
# 2020-11-18     7188.0
# ...               ...
# 2020-02-24        6.0
# 2020-02-21        6.0
# 2020-02-16        5.0
# 2020-02-08        4.0
# 2020-01-31        1.0
#
# [273 rows x 5 columns]

# %%
def get_covid_data(df_name='df_bc_covid',globe=True):
    if globe:
            global df_bc_covid
    df_bc_covid = pd.read_csv(bc_cov19_url)
    df_bc_covid = df_bc_covid[df_bc_covid.prname == 'British Columbia']
    df_bc_covid = df_bc_covid[['date','numtoday','numtotal_last7','numdeathstoday','numdeaths_last7','numactive']]
    df_bc_covid = df_bc_covid.set_index('date')
    return df_bc_covid

# %%
df_bc_covid.sort_index(ascending=False)
# Out:
#             numtoday  numtotal_last7  numdeathstoday  numdeaths_last7  \
# date
# 2020-11-22         0          3176.0             0.0             41.0
# 2020-11-21         0          3835.0             0.0             41.0
# 2020-11-20       516          4489.0            10.0             41.0
# 2020-11-19       536          4590.0             1.0             33.0
# 2020-11-18       761          4648.0            10.0             36.0
# ...              ...             ...             ...              ...
# 2020-02-24         0             NaN             0.0              NaN
# 2020-02-21         1             NaN             0.0              NaN
# 2020-02-16         1             NaN             0.0              NaN
# 2020-02-08         3             NaN             0.0              NaN
# 2020-01-31         1             NaN             0.0              NaN
#
#             numactive
# date
# 2020-11-22     7666.0
# 2020-11-21     7666.0
# 2020-11-20     7666.0
# 2020-11-19     7431.0
# 2020-11-18     7188.0
# ...               ...
# 2020-02-24        6.0
# 2020-02-21        6.0
# 2020-02-16        5.0
# 2020-02-08        4.0
# 2020-01-31        1.0
#
# [273 rows x 5 columns]
